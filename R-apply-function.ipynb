# %% [markdown]
# # Funções Apply( )

# %%
#Importando os 4 DataFrames que serão usados(row.names=1 para não considerar como coluna da tabela):

# %%
chicago <- read.csv("weather-data/Chicago-C.csv",row.names=1)

# %%
houston <- read.csv("weather-data/Houston-C.csv",row.names=1)

# %%
newyork <- read.csv("weather-data/NewYork-C.csv",row.names=1)

# %%
sanfrancisco <- read.csv("weather-data/SanFrancisco-C.csv",row.names=1)

# %%
head(chicago)
# Out:
#                 Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# AvgHigh_C         0   2   8  15  21  27  29  28  24  17   9   2
# AvgLow_C         -8  -6  -1   5  11  17  20  19  14   8   1  -5
# AvgPrecip_mm     52  49  69  92 105 103 102 101  84  82  87  65
# DaysWithPrecip   10   8  11  11  11  10   9   9   8  10  11  11
# HoursOfSunshine 135 136 187 215 281 311 318 283 226 193 113 106

# %%
head(houston)
# Out:
#                 Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        17.2  19.1  22.8  26.4  30.2  33.0  34.3  34.7  32.1  27.8
# AvgLow_C          6.2   8.1  11.4  15.2  19.8  23.1  23.9  23.8  21.0  16.1
# AvgPrecip_mm     85.0  81.0  86.0  84.0 129.0 150.0  96.0  95.0 104.0 144.0
# DaysWithPrecip    9.0   9.0   8.0   6.0   8.0  10.0   9.0   8.0   8.0   7.0
# HoursOfSunshine 142.0 155.0 192.0 210.0 248.0 282.0 294.0 269.0 237.0 229.0
#                 Nov   Dec
# AvgHigh_C        22.5  17.9
# AvgLow_C         11.2   7.0
# AvgPrecip_mm    110.0  95.0
# DaysWithPrecip    8.0   9.0
# HoursOfSunshine 168.0 148.0

# %%
head(newyork)
# Out:
#                 Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C         3.8   5.5   9.9  15.7  21.5  26.3  29.3  28.4  24.4  18.3
# AvgLow_C         -3.1  -1.9   1.9   6.9  12.6  17.7  21.0  20.3  16.3  10.1
# AvgPrecip_mm     99.0  75.0 103.0 100.0 113.0  89.0 115.0 105.0 101.0  86.0
# DaysWithPrecip   11.0  10.0  12.0  11.0  11.0  10.0  11.0  10.0   8.0   8.0
# HoursOfSunshine 154.0 171.0 213.0 237.0 268.0 289.0 302.0 271.0 235.0 213.0
#                 Nov   Dec
# AvgHigh_C        12.3   6.6
# AvgLow_C          5.1  -0.1
# AvgPrecip_mm     97.0  91.0
# DaysWithPrecip    9.0  10.0
# HoursOfSunshine 169.0 155.0

# %%
head(sanfrancisco)
# Out:
#                 Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        13.8  15.7  16.6  17.3  17.9  19.1  19.2  20.1  21.2  20.7
# AvgLow_C          7.6   8.6   9.2   9.6  10.6  11.6  12.2  12.8  12.8  12.1
# AvgPrecip_mm    114.0 113.0  83.0  37.0  18.0   4.0   0.0   2.0   5.0  28.0
# DaysWithPrecip   11.0  11.0  10.0   6.0   4.0   2.0   1.0   1.0   1.0   4.0
# HoursOfSunshine 165.0 182.0 251.0 281.0 314.0 330.0 300.0 272.0 267.0 243.0
#                 Nov   Dec
# AvgHigh_C        17.3  13.9
# AvgLow_C         10.1   7.8
# AvgPrecip_mm     80.0 116.0
# DaysWithPrecip    7.0  10.0
# HoursOfSunshine 189.0 156.0

# %%
# Tranformando os DataFrames em Matrizes
chicago <- as.matrix(chicago)
houston <- as.matrix(houston)
newyork <- as.matrix(newyork)
sanfrancisco <- as.matrix(sanfrancisco)

# %%
# Colocando todas as matrizes em uma Lista
Weather <- list(chicago=chicago,houston=houston,newyork=newyork,sanfrancisco=sanfrancisco)

# %%
Weather
# Out:
# $chicago
#                 Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# AvgHigh_C         0   2   8  15  21  27  29  28  24  17   9   2
# AvgLow_C         -8  -6  -1   5  11  17  20  19  14   8   1  -5
# AvgPrecip_mm     52  49  69  92 105 103 102 101  84  82  87  65
# DaysWithPrecip   10   8  11  11  11  10   9   9   8  10  11  11
# HoursOfSunshine 135 136 187 215 281 311 318 283 226 193 113 106
#
# $houston
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        17.2  19.1  22.8  26.4  30.2  33.0  34.3  34.7  32.1  27.8
# AvgLow_C          6.2   8.1  11.4  15.2  19.8  23.1  23.9  23.8  21.0  16.1
# AvgPrecip_mm     85.0  81.0  86.0  84.0 129.0 150.0  96.0  95.0 104.0 144.0
# DaysWithPrecip    9.0   9.0   8.0   6.0   8.0  10.0   9.0   8.0   8.0   7.0
# HoursOfSunshine 142.0 155.0 192.0 210.0 248.0 282.0 294.0 269.0 237.0 229.0
#                   Nov   Dec
# AvgHigh_C        22.5  17.9
# AvgLow_C         11.2   7.0
# AvgPrecip_mm    110.0  95.0
# DaysWithPrecip    8.0   9.0
# HoursOfSunshine 168.0 148.0
#
# $newyork
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C         3.8   5.5   9.9  15.7  21.5  26.3  29.3  28.4  24.4  18.3
# AvgLow_C         -3.1  -1.9   1.9   6.9  12.6  17.7  21.0  20.3  16.3  10.1
# AvgPrecip_mm     99.0  75.0 103.0 100.0 113.0  89.0 115.0 105.0 101.0  86.0
# DaysWithPrecip   11.0  10.0  12.0  11.0  11.0  10.0  11.0  10.0   8.0   8.0
# HoursOfSunshine 154.0 171.0 213.0 237.0 268.0 289.0 302.0 271.0 235.0 213.0
#                   Nov   Dec
# AvgHigh_C        12.3   6.6
# AvgLow_C          5.1  -0.1
# AvgPrecip_mm     97.0  91.0
# DaysWithPrecip    9.0  10.0
# HoursOfSunshine 169.0 155.0
#
# $sanfrancisco
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        13.8  15.7  16.6  17.3  17.9  19.1  19.2  20.1  21.2  20.7
# AvgLow_C          7.6   8.6   9.2   9.6  10.6  11.6  12.2  12.8  12.8  12.1
# AvgPrecip_mm    114.0 113.0  83.0  37.0  18.0   4.0   0.0   2.0   5.0  28.0
# DaysWithPrecip   11.0  11.0  10.0   6.0   4.0   2.0   1.0   1.0   1.0   4.0
# HoursOfSunshine 165.0 182.0 251.0 281.0 314.0 330.0 300.0 272.0 267.0 243.0
#                   Nov   Dec
# AvgHigh_C        17.3  13.9
# AvgLow_C         10.1   7.8
# AvgPrecip_mm     80.0 116.0
# DaysWithPrecip    7.0  10.0
# HoursOfSunshine 189.0 156.0

# %% [markdown]
# # APPLY()

# %%
# Função apply(data,linha ou coluna,função)
# para aplicar por linhas: apply(M,1, mean)
# para aplicar por colunas:apply(M,2, mean)
apply(chicago,1,mean)
# Out:
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#       15.166667        6.250000       82.583333        9.916667      208.666667

# %%
apply(houston,1,mean)
# Out:
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#        26.50000        15.56667       104.91667         8.25000       214.50000

# %%
apply(newyork,1,mean)
# Out:
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#        16.83333         8.90000        97.83333        10.08333       223.08333

# %%
apply(sanfrancisco,1,mean)
# Out:
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#       17.733333       10.416667       50.000000        5.666667      245.833333

# %% [markdown]
# # LAPPLY()

# %%
# Aplica apply() em listas e vetores

# %%
# Fazendo matriz transposta utilizando a função lapply()
nova_lista <- lapply(Weather, t)

# %%
nova_lista
# Out:
# $chicago
#     AvgHigh_C AvgLow_C AvgPrecip_mm DaysWithPrecip HoursOfSunshine
# Jan         0       -8           52             10             135
# Feb         2       -6           49              8             136
# Mar         8       -1           69             11             187
# Apr        15        5           92             11             215
# May        21       11          105             11             281
# Jun        27       17          103             10             311
# Jul        29       20          102              9             318
# Aug        28       19          101              9             283
# Sep        24       14           84              8             226
# Oct        17        8           82             10             193
# Nov         9        1           87             11             113
# Dec         2       -5           65             11             106
#
# $houston
#     AvgHigh_C AvgLow_C AvgPrecip_mm DaysWithPrecip HoursOfSunshine
# Jan      17.2      6.2           85              9             142
# Feb      19.1      8.1           81              9             155
# Mar      22.8     11.4           86              8             192
# Apr      26.4     15.2           84              6             210
# May      30.2     19.8          129              8             248
# Jun      33.0     23.1          150             10             282
# Jul      34.3     23.9           96              9             294
# Aug      34.7     23.8           95              8             269
# Sep      32.1     21.0          104              8             237
# Oct      27.8     16.1          144              7             229
# Nov      22.5     11.2          110              8             168
# Dec      17.9      7.0           95              9             148
#
# $newyork
#     AvgHigh_C AvgLow_C AvgPrecip_mm DaysWithPrecip HoursOfSunshine
# Jan       3.8     -3.1           99             11             154
# Feb       5.5     -1.9           75             10             171
# Mar       9.9      1.9          103             12             213
# Apr      15.7      6.9          100             11             237
# May      21.5     12.6          113             11             268
# Jun      26.3     17.7           89             10             289
# Jul      29.3     21.0          115             11             302
# Aug      28.4     20.3          105             10             271
# Sep      24.4     16.3          101              8             235
# Oct      18.3     10.1           86              8             213
# Nov      12.3      5.1           97              9             169
# Dec       6.6     -0.1           91             10             155
#
# $sanfrancisco
#     AvgHigh_C AvgLow_C AvgPrecip_mm DaysWithPrecip HoursOfSunshine
# Jan      13.8      7.6          114             11             165
# Feb      15.7      8.6          113             11             182
# Mar      16.6      9.2           83             10             251
# Apr      17.3      9.6           37              6             281
# May      17.9     10.6           18              4             314
# Jun      19.1     11.6            4              2             330
# Jul      19.2     12.2            0              1             300
# Aug      20.1     12.8            2              1             272
# Sep      21.2     12.8            5              1             267
# Oct      20.7     12.1           28              4             243
# Nov      17.3     10.1           80              7             189
# Dec      13.9      7.8          116             10             156

# %%
# ROWMEANS() mais facil que aplicar 4x apply(data,1,mean)
lapply(Weather, rowMeans)
# Existem outras, exemplos:
#rowMeans
#colMeans
#rowSums
#colSums
# Out:
# $chicago
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#       15.166667        6.250000       82.583333        9.916667      208.666667
#
# $houston
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#        26.50000        15.56667       104.91667         8.25000       214.50000
#
# $newyork
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#        16.83333         8.90000        97.83333        10.08333       223.08333
#
# $sanfrancisco
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#       17.733333       10.416667       50.000000        5.666667      245.833333

# %%
# Extrair a temperatura mais alta de janeiro de todas as cidades SEM o lapply():
Weather[[1]][1,1]
Weather[[2]][1,1]
Weather[[3]][1,1]
Weather[[4]][1,1]
# Out:
# [1] 0
# [1] 17.2
# [1] 3.8
# [1] 13.8

# %%
# Usando lapply()
lapply(Weather,"[",1,1)
# Out:
# $chicago
# [1] 0
#
# $houston
# [1] 17.2
#
# $newyork
# [1] 3.8
#
# $sanfrancisco
# [1] 13.8

# %%
# Usando lapply() todos os valores do mês de março
lapply(Weather,"[", ,3)
# Out:
# $chicago
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#               8              -1              69              11             187
#
# $houston
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#            22.8            11.4            86.0             8.0           192.0
#
# $newyork
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#             9.9             1.9           103.0            12.0           213.0
#
# $sanfrancisco
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#            16.6             9.2            83.0            10.0           251.0

# %%
mean(Weather$chicago[[2]][1])
# Out:
# [1] -8

# %%
Weather
# Out:
# $chicago
#                 Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# AvgHigh_C         0   2   8  15  21  27  29  28  24  17   9   2
# AvgLow_C         -8  -6  -1   5  11  17  20  19  14   8   1  -5
# AvgPrecip_mm     52  49  69  92 105 103 102 101  84  82  87  65
# DaysWithPrecip   10   8  11  11  11  10   9   9   8  10  11  11
# HoursOfSunshine 135 136 187 215 281 311 318 283 226 193 113 106
#
# $houston
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        17.2  19.1  22.8  26.4  30.2  33.0  34.3  34.7  32.1  27.8
# AvgLow_C          6.2   8.1  11.4  15.2  19.8  23.1  23.9  23.8  21.0  16.1
# AvgPrecip_mm     85.0  81.0  86.0  84.0 129.0 150.0  96.0  95.0 104.0 144.0
# DaysWithPrecip    9.0   9.0   8.0   6.0   8.0  10.0   9.0   8.0   8.0   7.0
# HoursOfSunshine 142.0 155.0 192.0 210.0 248.0 282.0 294.0 269.0 237.0 229.0
#                   Nov   Dec
# AvgHigh_C        22.5  17.9
# AvgLow_C         11.2   7.0
# AvgPrecip_mm    110.0  95.0
# DaysWithPrecip    8.0   9.0
# HoursOfSunshine 168.0 148.0
#
# $newyork
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C         3.8   5.5   9.9  15.7  21.5  26.3  29.3  28.4  24.4  18.3
# AvgLow_C         -3.1  -1.9   1.9   6.9  12.6  17.7  21.0  20.3  16.3  10.1
# AvgPrecip_mm     99.0  75.0 103.0 100.0 113.0  89.0 115.0 105.0 101.0  86.0
# DaysWithPrecip   11.0  10.0  12.0  11.0  11.0  10.0  11.0  10.0   8.0   8.0
# HoursOfSunshine 154.0 171.0 213.0 237.0 268.0 289.0 302.0 271.0 235.0 213.0
#                   Nov   Dec
# AvgHigh_C        12.3   6.6
# AvgLow_C          5.1  -0.1
# AvgPrecip_mm     97.0  91.0
# DaysWithPrecip    9.0  10.0
# HoursOfSunshine 169.0 155.0
#
# $sanfrancisco
#                   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct
# AvgHigh_C        13.8  15.7  16.6  17.3  17.9  19.1  19.2  20.1  21.2  20.7
# AvgLow_C          7.6   8.6   9.2   9.6  10.6  11.6  12.2  12.8  12.8  12.1
# AvgPrecip_mm    114.0 113.0  83.0  37.0  18.0   4.0   0.0   2.0   5.0  28.0
# DaysWithPrecip   11.0  11.0  10.0   6.0   4.0   2.0   1.0   1.0   1.0   4.0
# HoursOfSunshine 165.0 182.0 251.0 281.0 314.0 330.0 300.0 272.0 267.0 243.0
#                   Nov   Dec
# AvgHigh_C        17.3  13.9
# AvgLow_C         10.1   7.8
# AvgPrecip_mm     80.0 116.0
# DaysWithPrecip    7.0  10.0
# HoursOfSunshine 189.0 156.0

# %%
# Exibir a primeira linha de todas as cidades (AvgHigh_C) todos os meses do ano
lapply(Weather, function(x) x[1,])
# Out:
# $chicago
# Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
#   0   2   8  15  21  27  29  28  24  17   9   2
#
# $houston
#  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 17.2 19.1 22.8 26.4 30.2 33.0 34.3 34.7 32.1 27.8 22.5 17.9
#
# $newyork
#  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
#  3.8  5.5  9.9 15.7 21.5 26.3 29.3 28.4 24.4 18.3 12.3  6.6
#
# $sanfrancisco
#  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 13.8 15.7 16.6 17.3 17.9 19.1 19.2 20.1 21.2 20.7 17.3 13.9

# %%
# Exibir dados o mês de dezembro de todas as cidades
lapply(Weather, function(x) x[,12])
# Out:
# $chicago
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#               2              -5              65              11             106
#
# $houston
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#            17.9             7.0            95.0             9.0           148.0
#
# $newyork
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#             6.6            -0.1            91.0            10.0           155.0
#
# $sanfrancisco
#       AvgHigh_C        AvgLow_C    AvgPrecip_mm  DaysWithPrecip HoursOfSunshine
#            13.9             7.8           116.0            10.0           156.0

# %%
# Mostrando a diferença da temperatura max x min / min 
lapply(Weather, function(z) round((z[1,]-z[2,])/z[2,],2))
# Out:
# $chicago
#   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# -1.00 -1.33 -9.00  2.00  0.91  0.59  0.45  0.47  0.71  1.12  8.00 -1.40
#
# $houston
#  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 1.77 1.36 1.00 0.74 0.53 0.43 0.44 0.46 0.53 0.73 1.01 1.56
#
# $newyork
#    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov
#  -2.23  -3.89   4.21   1.28   0.71   0.49   0.40   0.40   0.50   0.81   1.41
#    Dec
# -67.00
#
# $sanfrancisco
#  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0.82 0.83 0.80 0.80 0.69 0.65 0.57 0.57 0.66 0.71 0.71 0.78

# %% [markdown]
# # SAPPLY()

# %%
# Sapply (mesma funçao que acima, so trocando o lapply por sapply)
sapply(Weather, function(z) round((z[1,]-z[2,])/z[2,],2))
# Out:
#     chicago houston newyork sanfrancisco
# Jan -1.00   1.77     -2.23  0.82
# Feb -1.33   1.36     -3.89  0.83
# Mar -9.00   1.00      4.21  0.80
# Apr  2.00   0.74      1.28  0.80
# May  0.91   0.53      0.71  0.69
# Jun  0.59   0.43      0.49  0.65
# Jul  0.45   0.44      0.40  0.57
# Aug  0.47   0.46      0.40  0.57
# Sep  0.71   0.53      0.50  0.66
# Oct  1.12   0.73      0.81  0.71
# Nov  8.00   1.01      1.41  0.71
# Dec -1.40   1.56    -67.00  0.78

# %%
round(sapply(Weather, rowMeans), 2)
# Out:
#                 chicago houston newyork sanfrancisco
# AvgHigh_C        15.17   26.50   16.83   17.73
# AvgLow_C          6.25   15.57    8.90   10.42
# AvgPrecip_mm     82.58  104.92   97.83   50.00
# DaysWithPrecip    9.92    8.25   10.08    5.67
# HoursOfSunshine 208.67  214.50  223.08  245.83

# %% [markdown]
# # NESTING APPLY()

# %%
# MÁXIMO de cada coluna de cada cidade:
sapply(Weather, apply, 1, max)
# Out:
#                 chicago houston newyork sanfrancisco
# AvgHigh_C        29      34.7    29.3    21.2
# AvgLow_C         20      23.9    21.0    12.8
# AvgPrecip_mm    105     150.0   115.0   116.0
# DaysWithPrecip   11      10.0    12.0    11.0
# HoursOfSunshine 318     294.0   302.0   330.0

# %%
# MÍNIMO de cada coluna de cada cidade:
sapply(Weather, apply, 1, min)
# Out:
#                 chicago houston newyork sanfrancisco
# AvgHigh_C         0      17.2     3.8    13.8
# AvgLow_C         -8       6.2    -3.1     7.6
# AvgPrecip_mm     49      81.0    75.0     0.0
# DaysWithPrecip    8       6.0     8.0     1.0
# HoursOfSunshine 106     142.0   154.0   156.0

# %% [markdown]
# # WHICH.MAX()

# %%
# Retorna a posiçao e valor do MAIOR valor da linha selecionada
which.max(chicago[1,])
# Out:
# Jul
#   7

# %%
sapply(Weather, function(y) apply(y,1,function(x) names(which.max(x))))
# Out:
#                 chicago houston newyork sanfrancisco
# AvgHigh_C       Jul     Aug     Jul     Sep
# AvgLow_C        Jul     Jul     Jul     Aug
# AvgPrecip_mm    May     Jun     Jul     Dec
# DaysWithPrecip  Mar     Jun     Mar     Jan
# HoursOfSunshine Jul     Jul     Jul     Jun

# %% [markdown]
# # WHICH.MIN()

# %%
sapply(Weather, function(y) apply(y,1,function(x) names(which.min(x))))
# Out:
#                 chicago houston newyork sanfrancisco
# AvgHigh_C       Jan     Jan     Jan     Jan
# AvgLow_C        Jan     Jan     Jan     Jan
# AvgPrecip_mm    Feb     Feb     Feb     Jul
# DaysWithPrecip  Feb     Apr     Sep     Jul
# HoursOfSunshine Dec     Jan     Jan     Dec
